# %%
# Incase you don't have faker installed
! pip3 install faker
# Out:
# Requirement already satisfied: faker in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (33.0.0)
# Requirement already satisfied: python-dateutil>=2.4 in /Users/nono/Library/Python/3.12/lib/python/site-packages (from faker) (2.9.0.post0)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from faker) (4.11.0)
# Requirement already satisfied: six>=1.5 in /Users/nono/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.4->faker) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
import pandas as pd
import random
from faker import Faker

fake = Faker()

# Global Variables
user_num = 1000
venue_num = 20
event_num = 300
payment_num = 1400
order_num = 1200
ticket_num = 1000
seat_num = 200
venues = []

# Users
users = []
roles = ['admin', 'user', 'organizer']
weights = [0.1, 0.7, 0.2]
for i in range(user_num):
    user = {
        "user_id": i,
        "username": fake.user_name(),
        "password": fake.password(),
        "email": fake.email(),
        "phone": fake.phone_number(),
        "role": random.choices(roles, weights)[0],
        "created_at": fake.date_time_this_year()
    }
    users.append(user)
    
users_df = pd.DataFrame(users)
users_df.to_csv("users.csv", index=False)
print(users_df)

# Some variables
admin_users = users_df[users_df['role'] == 'admin'].count()[0]
user_users = users_df[users_df['role'] == 'user'].count()[0]
organizer_users = users_df[users_df['role'] == 'organizer'].count()[0]
organizers = users_df[users_df['role'] == 'organizer']

print(f"Admin Users: {admin_users}")
print(f"User Users: {user_users}")
print(f"Organizer Users: {organizer_users}")
# Out:
#      user_id            username    password                         email  \
# 0          0   schwartzchristine  *#dY2J4k%s     gregorybrooks@example.net
# 1          1         murphydonna  E%1oZhwhnZ        pameladunn@example.org
# 2          2              kara14  K0L7DdzI%s       evelynmills@example.com
# 3          3           kcantrell  )oOJc!SJC7      oconnormegan@example.org
# 4          4       gregoryharris  dh4SuuPf#_     garciagabriel@example.org
# ..       ...                 ...         ...                           ...
# 995      995  mitchellkristopher  u%117Tsf1S       matthewwest@example.org
# 996      996        davistimothy  #3Z^+3Ra_Z         suzanne87@example.org
# 997      997           smitheric  61F#&Wnj+a         xreynolds@example.com
# 998      998       coopermarissa  VK6U9u_pS_  martinezvirginia@example.net
# 999      999     breannamarshall  19NAOuVs*4          alicia02@example.net
#
#                    phone       role                 created_at
# 0       265.782.2726x722      admin 2024-06-26 08:42:44.080904
# 1          (875)833-6170  organizer 2024-07-23 09:04:49.315919
# 2          (373)238-7189       user 2024-01-04 22:29:37.949148
# 3        +1-376-555-3947       user 2024-01-24 08:24:31.186425
# 4    +1-892-809-3396x512  organizer 2024-01-29 13:20:55.501187
# ..                   ...        ...                        ...
# 995           4009603785  organizer 2024-06-04 01:20:21.453350
# 996   697.643.9393x72114       user 2024-08-18 20:35:58.408592
# 997  +1-550-972-5524x562       user 2024-06-21 16:31:39.790140
# 998    (577)282-8369x661       user 2024-07-29 09:01:46.826895
# 999           7965816003       user 2024-11-30 13:28:17.265599
#
# [1000 rows x 7 columns]
# Admin Users: 92
# User Users: 708
# Organizer Users: 200
# /var/folders/p_/wcg3qcf14tjcjw_8md95qf_m0000gn/T/ipykernel_32579/3847770533.py:38: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   admin_users = users_df[users_df['role'] == 'admin'].count()[0]
# /var/folders/p_/wcg3qcf14tjcjw_8md95qf_m0000gn/T/ipykernel_32579/3847770533.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   user_users = users_df[users_df['role'] == 'user'].count()[0]
# /var/folders/p_/wcg3qcf14tjcjw_8md95qf_m0000gn/T/ipykernel_32579/3847770533.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   organizer_users = users_df[users_df['role'] == 'organizer'].count()[0]

# %%
# Venues
for i in range(1, venue_num + 1):
    venues.append({
        "venue_id": i,
        "venue_name": fake.company(),
        "address": fake.address(),
        "city": fake.city(),
        "capacity": random.randint(1000, 10000)
    })
venues_df = pd.DataFrame(venues)
venues_df.to_csv("venues.csv", index=False)

print(venues_df)
# Out:
#     venue_id                   venue_name  \
# 0          1    Harrison, Garcia and Hill
# 1          2                    Lewis LLC
# 2          3            Williams and Sons
# 3          4                    Ramos Inc
# 4          5       Meyer, Luna and Thomas
# 5          6   Christensen, Chen and Rose
# 6          7      Cook, Foster and Wilson
# 7          8                   Pruitt PLC
# 8          9              Wright-Gonzalez
# 9         10               Bennett-Nelson
# 10        11     Rubio, Murray and Brooks
# 11        12   Ramirez, James and Dickson
# 12        13              Mcdonald-Morgan
# 13        14                   Meyers LLC
# 14        15   Stevens, Brown and Freeman
# 15        16           Hale, Cox and King
# 16        17  Villarreal, Perez and Smith
# 17        18   Crawford, Davis and Taylor
# 18        19                 Kelley Group
# 19        20                    Smith PLC
#
#                                               address              city  \
# 0                  271 Sarah Via\nSaraville, KS 60789      Robynborough
# 1   69540 Robert Freeway Apt. 972\nWest Paulton, W...       Rebeccafort
# 2      31432 Ferguson Freeway\nLake Caitlin, ID 65142        Jamesshire
# 3          642 Jennifer Lights\nSummerburgh, PA 18089   South Jasonfort
# 4   3425 Johnson Stravenue Apt. 469\nNorth Lawrenc...          Josefort
# 5   96007 Aaron Estate Suite 122\nHutchinsonside, ...         Hallville
# 6   75141 Sanchez Unions Suite 111\nPort Zacharyto...          Clarkton
# 7   7656 Julia Throughway Suite 848\nStanleytown, ...  Christinaborough
# 8   764 Richards Mission Apt. 034\nKevinfort, PA 4...     Port Johnland
# 9               549 Hoffman Isle\nNew Wendy, LA 79851        Lake Jared
# 10  5899 Estrada Hollow\nWest Dustinborough, MI 00969       New Melissa
# 11             51651 Scott Meadow\nEmmaside, VT 52144  Lake Christopher
# 12       3516 Susan Mission\nValenzuelatown, RI 60933         Scottstad
# 13              345 Charles Row\nPort David, VT 20391       Fisherville
# 14  409 Stephen Spring Suite 433\nNorth Nathaniel,...         Susanside
# 15       283 Poole Key Apt. 584\nSmithville, SC 85393        New Colton
# 16                           USNV Lynch\nFPO AE 95735       South Susan
# 17                   Unit 0296 Box 4060\nDPO AP 61800      New Margaret
# 18  206 Robert Village Suite 722\nWalkerland, MO 7...     Spearschester
# 19                   PSC 6708, Box 7576\nAPO AE 15652  East Trevorhaven
#
#     capacity
# 0       9591
# 1       3963
# 2       2320
# 3       2523
# 4       3060
# 5       3035
# 6       5429
# 7       4632
# 8       7401
# 9       3250
# 10      8580
# 11      6270
# 12      6227
# 13      1571
# 14      7227
# 15      6885
# 16      5127
# 17      2250
# 18      6142
# 19      3020

# %%
# Events
events = []
statuses = ["Scheduled", "Canceled", "Completed"]
statuses_weights = [0.7, 0.1, 0.2]
for i in range(1, event_num + 1):
    events.append({
        "event_id": i,
        "event_name": fake.catch_phrase(),
        "performer": fake.name(),
        "event_date": fake.date_this_year(),
        "venue_id": random.randint(1, venue_num),
        "organizer_id": random.choice(organizers['user_id'].tolist()),
        "status": random.choices(statuses, statuses_weights)[0],
    })
events_df = pd.DataFrame(events)
events_df.to_csv("events.csv", index=False)

print(events_df)
# Out:
#      event_id                                     event_name  \
# 0           1        Total asynchronous budgetary management
# 1           2                      Managed reciprocal portal
# 2           3             Progressive client-server capacity
# 3           4                    Diverse high-level solution
# 4           5                    Robust explicit application
# ..        ...                                            ...
# 295       296               Organized human-resource ability
# 296       297               Persistent client-driven concept
# 297       298          Centralized intangible infrastructure
# 298       299  Diverse demand-driven artificial intelligence
# 299       300             Diverse asynchronous collaboration
#
#              performer  event_date  venue_id  organizer_id     status
# 0       Sylvia Hartman  2024-01-13         2           169  Scheduled
# 1          Austin Hall  2024-05-21        10           854  Scheduled
# 2       Erin Gallagher  2024-09-15         6           406  Scheduled
# 3    Alexandra Sanchez  2024-11-13        16           385  Scheduled
# 4    Courtney Adams MD  2024-04-23        19           406  Scheduled
# ..                 ...         ...       ...           ...        ...
# 295     Christina Hall  2024-04-23        11           491  Scheduled
# 296       Robert Floyd  2024-10-23        16            49  Completed
# 297     Calvin Jackson  2024-01-30        15           478  Scheduled
# 298      Jessica Smith  2024-08-13        18           291  Scheduled
# 299        Seth Martin  2024-10-03        10           481  Scheduled
#
# [300 rows x 7 columns]

# %%
# Seats
seats = []
seat_types = ["Regular", "VIP", "Wheelchair"]
seat_types_weights = [0.7, 0.2, 0.1]
for venue_id in range(1, venue_num + 1):
    for seat_number in range(1, 1000):  # 1000 seats per venue
        seats.append({
            "venue_id": venue_id,
            "seat_number": seat_number,
            "section": f"Section-{random.randint(1, 10)}",
            "row": f"Row-{random.randint(1, 40)}",
            "seat_type": random.choices(seat_types, seat_types_weights)[0],
        })
seats_df = pd.DataFrame(seats)
seats_df.to_csv("seats.csv", index=False)

print(seats_df)
# Out:
#        venue_id  seat_number     section     row   seat_type
# 0             1            1   Section-6  Row-28     Regular
# 1             1            2   Section-3  Row-17     Regular
# 2             1            3   Section-5  Row-18     Regular
# 3             1            4   Section-7  Row-35     Regular
# 4             1            5   Section-7  Row-24     Regular
# ...         ...          ...         ...     ...         ...
# 19975        20          995   Section-7   Row-8     Regular
# 19976        20          996   Section-9  Row-22     Regular
# 19977        20          997   Section-9  Row-33  Wheelchair
# 19978        20          998  Section-10   Row-5     Regular
# 19979        20          999   Section-7  Row-32         VIP
#
# [19980 rows x 5 columns]

# %%
# ORDER
orders = []
payments = []
tickets = []
order_statuses = ["Pending", "Paid", "Canceled"]
ticket_statuses = ["Available", "Reserved", "Sold"]
payment_methods = ["Credit Card", "PayPal", "Bank Transfer"]
payment_statuses = ["Pending", "Completed", "Failed"]
payment_statuses_weights = [0.7, 0.2, 0.1]
ticket_statuses_weights = [0.7, 0.2, 0.1]
order_statuses_weights = [0.7, 0.2, 0.1]
for i in range(1, order_num + 1):
    orders.append({
        "order_id": i,
        "user_id": random.randint(1, user_users),
        "total_amount": round(random.uniform(100, 1000), 2),
        "order_date": fake.date_time_this_year(),
        "status": random.choices(order_statuses, order_statuses_weights)[0],
    })
    
    if (orders[i-1]['status'] == 'Paid'):
        total_amount = 0
        for j in range(random.randint(1, 5)):
            ticket = {
                "ticket_id": len(tickets) + 1,
                "event_id": random.randint(1, event_num + 1),
                "seat_number": random.randint(1, 1000),
                "price": round(random.uniform(50, 200), 2),
                "status": random.choices(ticket_statuses, ticket_statuses_weights)[0],
            }
            tickets.append(ticket)
            total_amount += ticket['price']

        payment = {
            "payment_id": len(payments) + 1,
            "order_id": i,
            "payment_date": fake.date_time_this_year(),
            "amount": total_amount,
            "method": random.choice(payment_methods),
            "status": "Completed",
        }
        payments.append(payment)
        
orders_df = pd.DataFrame(orders)
orders_df.to_csv("orders.csv", index=False)

payments_df = pd.DataFrame(payments)
payments_df.to_csv("payments.csv", index=False)

tickets_df = pd.DataFrame(tickets)
tickets_df.to_csv("tickets.csv", index=False)

print(orders_df)
# Out:
#       order_id  user_id  total_amount                 order_date    status
# 0            1      130        851.12 2024-06-28 09:09:23.560186   Pending
# 1            2      491        671.84 2024-09-07 22:43:49.655293      Paid
# 2            3      580        177.51 2024-03-17 04:41:08.162074  Canceled
# 3            4      446        646.41 2024-01-08 01:17:20.181578   Pending
# 4            5      137        274.45 2024-08-18 20:00:46.206712  Canceled
# ...        ...      ...           ...                        ...       ...
# 1195      1196      469        869.89 2024-02-01 01:44:45.158487   Pending
# 1196      1197      349        813.68 2024-10-31 07:25:39.008075   Pending
# 1197      1198       24        467.20 2024-05-07 16:04:11.287846   Pending
# 1198      1199      492        889.10 2024-07-24 02:12:11.655109   Pending
# 1199      1200       72        677.26 2024-05-01 13:49:00.255532   Pending
#
# [1200 rows x 5 columns]
