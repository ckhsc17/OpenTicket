# %%
# Incase you don't have faker installed
! pip3 install faker
# Out:
# Requirement already satisfied: faker in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (33.0.0)
# Requirement already satisfied: python-dateutil>=2.4 in /Users/nono/Library/Python/3.12/lib/python/site-packages (from faker) (2.9.0.post0)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from faker) (4.11.0)
# Requirement already satisfied: six>=1.5 in /Users/nono/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.4->faker) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
import pandas as pd
import random
from faker import Faker

fake = Faker()

# Global Variables
user_num = 20000
venue_num = 20
event_num = 1300
payment_num = 5000
order_num = 10000
seat_num = 3000
venues = []

# Users
users = []
roles = ['admin', 'user', 'organizer']
weights = [0.1, 0.7, 0.2]
for i in range(1, user_num + 1):
    user = {
        "user_id": i,
        "username": fake.user_name(),
        "password": fake.password(),
        "email": fake.email(),
        "phone": fake.phone_number(),
        "role": random.choices(roles, weights)[0],
        "created_at": fake.date_this_decade()
    }
    users.append(user)
    
users_df = pd.DataFrame(users)
users_df.to_csv("users.csv", index=False)
print(users_df)

# Some variables
admin_users = users_df[users_df['role'] == 'admin'].count()[0]
user_users = users_df[users_df['role'] == 'user'].count()[0]
organizer_users = users_df[users_df['role'] == 'organizer'].count()[0]
organizers = users_df[users_df['role'] == 'organizer']

print(f"Admin Users: {admin_users}")
print(f"User Users: {user_users}")
print(f"Organizer Users: {organizer_users}")
# Out:
#        user_id       username    password                         email  \
# 0            1       bmorales  Y2Bo4V8V(K     armstrongryan@example.org
# 1            2   sheltonnorma  +2PBKmXI63        danielle52@example.org
# 2            3   sheilajensen  d$Lk2TtX1e            ncohen@example.org
# 3            4   ramosmiranda  b2DBbRtC+h         ryanolson@example.com
# 4            5    nguyendavid  Z(t3Hk&$IW  phillipwilkerson@example.org
# ...        ...            ...         ...                           ...
# 19995    19996      patrick72  F1vArQjX*k        lisacoffey@example.org
# 19996    19997  feliciamurphy  PUy0IWhsi@      brandonwhite@example.net
# 19997    19998       george90  #mKe7HevpR  alexanderdaniels@example.com
# 19998    19999       broberts  #UDbL(VeX3         lisabrown@example.com
# 19999    20000  davidmelendez  y^6s0ZEy@5      wallacederek@example.org
#
#                        phone       role  created_at
# 0      001-812-925-3585x0015       user  2024-11-30
# 1               789.970.1187       user  2022-02-18
# 2         611-658-1545x59113  organizer  2023-10-26
# 3               428-431-1164       user  2020-06-02
# 4       001-415-235-5581x005       user  2021-06-24
# ...                      ...        ...         ...
# 19995      (957)685-4651x405       user  2021-09-06
# 19996    +1-734-746-7431x543       user  2022-04-01
# 19997   +1-796-259-8506x2956       user  2022-01-22
# 19998          (510)424-1734       user  2024-05-07
# 19999     700-872-0028x54774       user  2020-04-24
#
# [20000 rows x 7 columns]
# Admin Users: 2033
# User Users: 13967
# Organizer Users: 4000
# /var/folders/p_/wcg3qcf14tjcjw_8md95qf_m0000gn/T/ipykernel_43968/1398830978.py:37: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   admin_users = users_df[users_df['role'] == 'admin'].count()[0]
# /var/folders/p_/wcg3qcf14tjcjw_8md95qf_m0000gn/T/ipykernel_43968/1398830978.py:38: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   user_users = users_df[users_df['role'] == 'user'].count()[0]
# /var/folders/p_/wcg3qcf14tjcjw_8md95qf_m0000gn/T/ipykernel_43968/1398830978.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   organizer_users = users_df[users_df['role'] == 'organizer'].count()[0]

# %%
# Venues
for i in range(1, venue_num + 1):
    venues.append({
        "venue_id": i,
        "venue_name": fake.company(),
        "address": fake.address(),
        "city": fake.city(),
        "capacity": random.randint(1000, 10000)
    })
venues_df = pd.DataFrame(venues)
venues_df.to_csv("venues.csv", index=False)

print(venues_df)
# Out:
#     venue_id                     venue_name  \
# 0          1         Garcia, Webb and Brown
# 1          2                     Nguyen Ltd
# 2          3  Rosario, Cochran and Harrison
# 3          4      Bennett, Sutton and White
# 4          5     Johnson, Houston and Smith
# 5          6              Humphrey-Thompson
# 6          7              Richardson-Taylor
# 7          8                    Snow-Brooks
# 8          9                      Smith PLC
# 9         10         Lopez, Jones and Rivas
# 10        11                      Potts LLC
# 11        12                  Hernandez PLC
# 12        13              Armstrong-Farrell
# 13        14                   Ayers-Castro
# 14        15               Vasquez-Anderson
# 15        16                     Brooks Inc
# 16        17                 Smith-Gonzalez
# 17        18                     Ortiz-Wise
# 18        19                Gardner-Barnett
# 19        20                    Lopez-Davis
#
#                                               address                  city  \
# 0                            USNS Price\nFPO AE 32573           Coopermouth
# 1           3776 Dawn Groves\nSouth Timothy, ME 92822            New Joshua
# 2   85396 Christine Corner Suite 764\nNew Amy, RI ...            Martinland
# 3              594 Johnson Trace\nJulietown, OR 03228            Jasonburgh
# 4   274 Valentine Haven Apt. 700\nWellsland, LA 56339          Rebeccahaven
# 5           32451 Heath Locks\nNew Kristine, PR 75008          Johnsonmouth
# 6     5333 Robin Lights Apt. 442\nJamesland, NC 95522       South Jasonfort
# 7    725 Danny Track Apt. 859\nKristinhaven, MH 01753    South Timothyshire
# 8   719 Clifford Viaduct Apt. 864\nJoneshaven, ME ...          Rebeccamouth
# 9   9354 Sanders Bridge Apt. 364\nHowardton, AZ 84273      South Janiceland
# 10  1360 Tara Motorway Apt. 740\nFrostville, SC 44993       North Kariville
# 11    136 Allen Canyon Apt. 847\nAmberhaven, AR 74160             Garciaton
# 12  4241 Rodriguez Loop Apt. 865\nNorth Donnachest...            New Brandi
# 13                          USS Roberts\nFPO AA 06781        Port Alexhaven
# 14  528 Robinson Rest Suite 469\nThompsonville, MP...  Port Christopherberg
# 15  0466 Montoya Parks Suite 880\nSouth Andrea, LA...           Owenborough
# 16            2879 Robin Green\nEast Dustin, MP 68411            Jonesmouth
# 17         0435 Matthew Lights\nReginaburgh, KS 58052           Griffinside
# 18      509 Mary Junction\nEast Matthewland, IN 50820           East Kaylee
# 19     1408 Gomez Fork Suite 227\nMooreport, TX 44667           Rebeccatown
#
#     capacity
# 0       4473
# 1       4208
# 2       9463
# 3       8444
# 4       4172
# 5       6954
# 6       7083
# 7       7615
# 8       9813
# 9       8723
# 10      7505
# 11      2847
# 12      4433
# 13      3804
# 14      2239
# 15      9913
# 16      4381
# 17      7918
# 18      7201
# 19      6970

# %%
# Events
events = []
organize = []
statuses = ["Scheduled", "Canceled", "Completed"]
statuses_weights = [0.7, 0.1, 0.2]
for i in range(1, event_num + 1):
    events.append({
        "event_id": i,
        "event_name": fake.catch_phrase(),
        "performer": fake.name(),
        "event_date": fake.date_this_year(),
        "venue_id": random.randint(1, venue_num),
        "organizer_id": random.choice(organizers['user_id'].tolist()),
        "status": random.choices(statuses, statuses_weights)[0],
        "description": fake.text()
    })
    
    organize.append({
        "organizer_id": events[-1]["organizer_id"],
        "event_id": i
    })
events_df = pd.DataFrame(events)
events_df.to_csv("events.csv", index=False)

organize_df = pd.DataFrame(organize)
organize_df.to_csv("organize.csv", index=False)

print(events_df)
# Out:
#       event_id                                     event_name  \
# 0            1                   Balanced web-enabled circuit
# 1            2           Customer-focused methodical extranet
# 2            3         Triple-buffered regional knowledgebase
# 3            4  Configurable user-facing budgetary management
# 4            5        Triple-buffered foreground secured line
# ...        ...                                            ...
# 1295      1296                     Diverse exuding capability
# 1296      1297           Object-based global customer loyalty
# 1297      1298       Re-contextualized web-enabled time-frame
# 1298      1299              Compatible transitional structure
# 1299      1300                    Multi-tiered local software
#
#                  performer  event_date  venue_id  organizer_id     status  \
# 0           Matthew Wright  2024-04-25        16          8153  Completed
# 1     Jeremy Velazquez DDS  2024-07-03         1         11518  Scheduled
# 2             Pamela Jones  2024-01-19         3         17345  Scheduled
# 3                Ann Young  2024-08-24        20          6195  Scheduled
# 4           Melissa Holmes  2024-04-21         9          7559   Canceled
# ...                    ...         ...       ...           ...        ...
# 1295     Kenneth Wilkinson  2024-10-27        19         19921  Scheduled
# 1296       James Henderson  2024-05-22        14          2469  Scheduled
# 1297          Tyler Miller  2024-05-21         2         14765  Scheduled
# 1298         Erin Peterson  2024-08-11         3         15873  Completed
# 1299      Lawrence Simpson  2024-12-19        11          8253  Scheduled
#
#                                             description
# 0     Performance policy degree lawyer job indicate ...
# 1     Measure leave once behind. Network any top law...
# 2     Scientist capital name word edge heavy. Proper...
# 3     Night yet along itself. Specific Democrat eigh...
# 4     Little while fast authority plant out indeed. ...
# ...                                                 ...
# 1295  Together mission responsibility street. Societ...
# 1296  Exactly to else purpose Congress. Performance ...
# 1297  Point order statement describe million box nat...
# 1298  Book their dinner perhaps exist charge modern....
# 1299  Often tonight place analysis other easy struct...
#
# [1300 rows x 8 columns]

# %%
# Seats
seats = []
seat_types = ["Regular", "VIP", "Wheelchair"]
seat_status = ["Available", "Reserved", "Sold"]
seat_status_weights = [0.7, 0.2, 0.1]
seat_types_weights = [0.7, 0.2, 0.1]
for venue_id in range(1, venue_num + 1):
    for seat_number in range(1, seat_num + 1):  # 1000 seats per venue
        section_num = int(seat_number / 30 / 10)
        row_num = int(seat_number / 30) % 10
        seats.append({
            "venue_id": venue_id,
            "seat_number": seat_number,
            "section": f"Section-{section_num}",
            "row": f"Row-{row_num}",
            "seat_type": random.choices(seat_types, seat_types_weights)[0],
            "status": random.choices(seat_status, seat_status_weights)[0],
        })
        
seats_df = pd.DataFrame(seats)

print(seats_df)
# Out:
#        venue_id  seat_number     section    row seat_type     status
# 0             1            1   Section-0  Row-0   Regular   Reserved
# 1             1            2   Section-0  Row-0       VIP   Reserved
# 2             1            3   Section-0  Row-0       VIP  Available
# 3             1            4   Section-0  Row-0       VIP  Available
# 4             1            5   Section-0  Row-0       VIP  Available
# ...         ...          ...         ...    ...       ...        ...
# 59995        20         2996   Section-9  Row-9   Regular  Available
# 59996        20         2997   Section-9  Row-9   Regular  Available
# 59997        20         2998   Section-9  Row-9   Regular   Reserved
# 59998        20         2999   Section-9  Row-9   Regular  Available
# 59999        20         3000  Section-10  Row-0   Regular   Reserved
#
# [60000 rows x 6 columns]

# %%
import pandas as pd
import random
import numpy as np
from faker import Faker


orders = []
payments = []
tickets = []
order_statuses = ["Paid", "Pending", "Canceled"]
ticket_statuses = ["Youth", "Adult", "Senior"] # youth, adult, senior
payment_methods = ["Credit Card", "PayPal", "Bank Transfer"]
payment_statuses = ["Pending", "Completed", "Failed"]
payment_statuses_weights = [0.7, 0.2, 0.1]
ticket_statuses_weights = [0.7, 0.2, 0.1]
order_statuses_weights = [0.7, 0.2, 0.1]
for i in range(1, order_num + 1):
    orders.append({
        "order_id": i,
        "user_id": random.randint(1, user_num),
        "total_amount": round(random.uniform(100, 1000), 2),
        "order_date": fake.date_time_this_year(),
        "status": random.choices(order_statuses, order_statuses_weights)[0],
    })
    
    if (orders[i-1]['status'] == 'Paid'):
        total_amount = 0
        for j in range(random.randint(1, 3)):
            event = random.randint(1, event_num)
            ticket = {
                "ticket_id": len(tickets) + 1,
                "event_id": event,
                "order_id": i,
                "venue_id": 0,
                "seat_number": 0,
                "price": round(random.uniform(50, 200), 2),
                "type": random.choices(ticket_statuses, ticket_statuses_weights)[0],
            }
            
            while True:
                seat = random.choice(seats)
                if (seat['status'] != "Available"):
                    continue
                if ((seat['venue_id'], seat['seat_number'], event) not in [(t['venue_id'], t['seat_number'], t['event_id']) for t in tickets]):
                    ticket['venue_id'] = seat['venue_id']
                    ticket['seat_number'] = seat['seat_number']
                    break
                
            tickets.append(ticket)
            total_amount += ticket['price']
            
            seat['status'] = "Sold"

        payment = {
            "payment_id": len(payments) + 1,
            "order_id": i,
            "payment_date": fake.date_time_this_year(),
            "amount": total_amount,
            "method": random.choice(payment_methods),
            "status": "Completed",
        }
        payments.append(payment)
    elif (orders[i-1]['status'] == 'Pending'):
        payment = {
            "payment_id": len(payments) + 1,
            "order_id": i,
            "payment_date": fake.date_time_this_year(),
            "amount": orders[i-1]['total_amount'],
            "method": random.choice(payment_methods),
            "status": "Pending",
        }
        payments.append(payment)
        
        
orders_df = pd.DataFrame(orders)
orders_df.to_csv("orders.csv", index=False)

payments_df = pd.DataFrame(payments)
payments_df.to_csv("payments.csv", index=False)

tickets_df = pd.DataFrame(tickets)
tickets_df.to_csv("tickets.csv", index=False)

seats_df = pd.DataFrame(seats)
seats_df.to_csv("seats.csv", index=False)

print(orders_df)
# Out:
#       order_id  user_id  total_amount                 order_date    status
# 0            1    19281        726.95 2024-08-07 22:52:02.994799      Paid
# 1            2     2046        688.51 2024-08-22 19:48:46.129659      Paid
# 2            3     9782        521.45 2024-08-13 05:49:43.176900  Canceled
# 3            4    13881        379.07 2024-09-21 12:42:42.653302      Paid
# 4            5     7049        163.76 2024-12-03 01:49:37.709522   Pending
# ...        ...      ...           ...                        ...       ...
# 9995      9996    15144        981.59 2024-07-20 19:48:22.292972   Pending
# 9996      9997     9987        728.32 2024-10-23 22:17:46.192613  Canceled
# 9997      9998    15110        423.42 2024-07-24 08:37:39.648916      Paid
# 9998      9999    16071        774.88 2024-04-04 08:18:08.549525   Pending
# 9999     10000     2839        135.89 2024-07-27 05:47:05.494855   Pending
#
# [10000 rows x 5 columns]

# %%
# check if every ticket has only appear once in every seat
