# %%
# Incase you don't have faker installed
! pip3 install faker
# Out:
# Requirement already satisfied: faker in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (33.0.0)
# Requirement already satisfied: python-dateutil>=2.4 in /Users/nono/Library/Python/3.12/lib/python/site-packages (from faker) (2.9.0.post0)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from faker) (4.11.0)
# Requirement already satisfied: six>=1.5 in /Users/nono/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.4->faker) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
import pandas as pd
import random
from faker import Faker

fake = Faker()

# Global Variables
user_num = 20000
venue_num = 20
event_num = 1300
payment_num = 5000
order_num = 10000
seat_num = 3000
venues = []

# Users
users = []
roles = ['admin', 'user', 'organizer']
weights = [0.1, 0.7, 0.2]
for i in range(1, user_num + 1):
    user = {
        "user_id": i,
        "username": fake.user_name(),
        "password": fake.password(),
        "email": fake.email(),
        "phone": fake.phone_number(),
        "role": random.choices(roles, weights)[0],
        "created_at": fake.date_this_decade()
    }
    users.append(user)
    
users_df = pd.DataFrame(users)
users_df.to_csv("users.csv", index=False)
print(users_df)

# Some variables
admin_users = users_df[users_df['role'] == 'admin'].count()[0]
user_users = users_df[users_df['role'] == 'user'].count()[0]
organizer_users = users_df[users_df['role'] == 'organizer'].count()[0]
organizers = users_df[users_df['role'] == 'organizer']

print(f"Admin Users: {admin_users}")
print(f"User Users: {user_users}")
print(f"Organizer Users: {organizer_users}")
# Out:
#        user_id        username    password                     email  \
# 0            1     millermegan  g+0A7dqMd%      angela28@example.org
# 1            2    sandranguyen  iA^c3VlC+Z    jameskline@example.net
# 2            3        therrera  Pm$Y5QxWKB        bgreer@example.com
# 3            4    barreralaura  Lf(0B8Oaj)   romerocindy@example.net
# 4            5      lopezrandy  %lMLih4cH8        lisa66@example.net
# ...        ...             ...         ...                       ...
# 19995    19996       pwilliams  Rd0GO1ed%7       harry03@example.net
# 19996    19997  stevenhamilton  )t0JpOGV)h       aaron79@example.org
# 19997    19998   hodgesrandall  Wn(5xYkPnM  matthewlewis@example.net
# 19998    19999        steven59  i2QDV^#v&3     patrick67@example.com
# 19999    20000       matthew60  $W0c(Cn(oo        mark05@example.com
#
#                       phone       role  created_at
# 0       +1-568-702-3528x554  organizer  2024-08-27
# 1      001-782-780-2451x870       user  2020-10-02
# 2        (841)300-6051x6185       user  2023-04-03
# 3             (926)253-3250      admin  2022-04-13
# 4        582.771.7296x45583       user  2020-09-28
# ...                     ...        ...         ...
# 19995          339.652.2006      admin  2021-05-15
# 19996    (916)445-7400x7402       user  2024-10-28
# 19997     446-911-9515x5696  organizer  2021-11-14
# 19998    208.628.3443x97309       user  2024-02-15
# 19999     642.311.7061x1847       user  2023-04-14
#
# [20000 rows x 7 columns]
# Admin Users: 2001
# User Users: 14031
# Organizer Users: 3968
# /var/folders/p_/wcg3qcf14tjcjw_8md95qf_m0000gn/T/ipykernel_42304/3396301955.py:38: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   admin_users = users_df[users_df['role'] == 'admin'].count()[0]
# /var/folders/p_/wcg3qcf14tjcjw_8md95qf_m0000gn/T/ipykernel_42304/3396301955.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   user_users = users_df[users_df['role'] == 'user'].count()[0]
# /var/folders/p_/wcg3qcf14tjcjw_8md95qf_m0000gn/T/ipykernel_42304/3396301955.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   organizer_users = users_df[users_df['role'] == 'organizer'].count()[0]

# %%
# Venues
for i in range(1, venue_num + 1):
    venues.append({
        "venue_id": i,
        "venue_name": fake.company(),
        "address": fake.address(),
        "city": fake.city(),
        "capacity": random.randint(1000, 10000)
    })
venues_df = pd.DataFrame(venues)
venues_df.to_csv("venues.csv", index=False)

print(venues_df)
# Out:
#     venue_id                       venue_name  \
# 0          1                       Becker LLC
# 1          2                    Smith-Watkins
# 2          3                       Wise-Moore
# 3          4    Taylor, Blackburn and Mueller
# 4          5                Johnson-Alexander
# 5          6          Vasquez, Barron and Cox
# 6          7  Myers, Fletcher and Fitzpatrick
# 7          8                   Coleman-Morris
# 8          9       Cortez, Garcia and Sanchez
# 9         10                   Williamson PLC
# 10        11                      Johnson LLC
# 11        12                     Jones-Vaughn
# 12        13                      Moore-Smith
# 13        14                   Stone-Thompson
# 14        15                  Martinez-Tucker
# 15        16     George, Alexander and Martin
# 16        17         Williams, Carey and Wood
# 17        18                      Sanchez Inc
# 18        19             Wolf, Mack and Jones
# 19        20        Taylor, Cooper and Torres
#
#                                               address              city  \
# 0                849 Yolanda Flat\nJohnstad, AK 18120   Port Josephview
# 1        1853 Mccormick Route\nWallaceburgh, ME 41438      Margaretfort
# 2    19297 May Route Suite 872\nJoshuaville, OR 35482         Jerometon
# 3               514 Reyes Camp\nSwansonstad, IL 66025     Cristianmouth
# 4   8531 Swanson Station Suite 551\nNorth Amy, NY ...  East Adrianhaven
# 5      238 Parker Square Suite 860\nAmybury, KS 67202         Lauraland
# 6   9164 Griffin Court Apt. 218\nAlvarezville, VT ...         Amandaton
# 7         8148 Nicholas Alley\nWest Amybury, PW 15107      North Kendra
# 8            64577 Maria Pass\nSouth Amanda, OK 06527        West Ricky
# 9   1451 Brown Station Suite 324\nEast Melissa, AL...        East Aaron
# 10  06415 Jeffery Course Apt. 072\nAllenbury, ID 6...       Fischerview
# 11  35896 Ian Circles Apt. 252\nHenrychester, SC 3...      Stewartshire
# 12          386 Bishop Mountain\nWest Larry, MN 66856        North Adam
# 13     69150 Elizabeth Stream\nNew Danabury, HI 50687          Ginabury
# 14  72377 Walker Unions Apt. 767\nNorth Brianna, V...        Johnsonton
# 15  978 Marissa Cliff Suite 673\nGuerrafurt, NY 22361        Murphyport
# 16  965 Manning Field Apt. 275\nPort Leonardside, ...     Santosborough
# 17             988 Watson Canyon\nMccoyberg, MI 10113        Jamieburgh
# 18  540 Allison Mountains Apt. 604\nHernandezbury,...          Lambfurt
# 19                   Unit 6266 Box 9424\nDPO AP 06505      Lake Rebecca
#
#     capacity
# 0       6280
# 1       7469
# 2       4398
# 3       5487
# 4       2304
# 5       8957
# 6       2925
# 7       6615
# 8       7330
# 9       5380
# 10      9690
# 11      6244
# 12      8946
# 13      7539
# 14      9213
# 15      1959
# 16      6878
# 17      8269
# 18      6712
# 19      5418

# %%
# Events
events = []
organize = []
statuses = ["Scheduled", "Canceled", "Completed"]
statuses_weights = [0.7, 0.1, 0.2]
for i in range(1, event_num + 1):
    events.append({
        "event_id": i,
        "event_name": fake.catch_phrase(),
        "performer": fake.name(),
        "event_date": fake.date_this_year(),
        "venue_id": random.randint(1, venue_num),
        "organizer_id": random.choice(organizers['user_id'].tolist()),
        "status": random.choices(statuses, statuses_weights)[0],
        "description": fake.text()
    })
    
    organize.append({
        "organizer_id": events[-1]["organizer_id"],
        "event_id": i
    })
events_df = pd.DataFrame(events)
events_df.to_csv("events.csv", index=False)

organize_df = pd.DataFrame(organize)
organize_df.to_csv("organize.csv", index=False)

print(events_df)
# Out:
#      event_id                                 event_name           performer  \
# 0           1         Compatible client-driven groupware         Todd Bailey
# 1           2        Horizontal demand-driven monitoring       Patricia Hill
# 2           3        Fundamental regional data-warehouse          Mary Davis
# 3           4        Ergonomic high-level conglomeration       Tyler Mendoza
# 4           5  Customer-focused 3rdgeneration encryption    Jessica Mcdaniel
# ..        ...                                        ...                 ...
# 295       296          Ameliorated mobile data-warehouse      Amy Pennington
# 296       297  Mandatory optimal artificial intelligence         James Boone
# 297       298        Re-contextualized coherent protocol  Melanie Willis DDS
# 298       299           Extended explicit conglomeration       Terry Pollard
# 299       300   Proactive grid-enabled open architecture      Stephanie Tran
#
#      event_date  venue_id  organizer_id     status  \
# 0    2024-04-17         7          6540  Scheduled
# 1    2024-02-06        12          4698  Scheduled
# 2    2024-07-24         3         17045  Scheduled
# 3    2024-12-03         2          3733  Completed
# 4    2024-10-06        15          7905  Scheduled
# ..          ...       ...           ...        ...
# 295  2024-03-02        20          1062  Completed
# 296  2024-07-07        16         10111  Scheduled
# 297  2024-05-04        17         16349  Completed
# 298  2024-10-21        12         12878  Completed
# 299  2024-09-20         1          5867  Scheduled
#
#                                            description
# 0    Often share on. Many region painting two north...
# 1    Stay receive statement never central person fo...
# 2    Chance cost school specific science them lose....
# 3    Order film body five film. Another voice at la...
# 4    Expect risk statement increase medical. Weight...
# ..                                                 ...
# 295  High yard subject onto voice research support....
# 296  Garden clearly use yeah indicate. Require stop...
# 297  Per person choose six space network. Ball them...
# 298  Doctor former animal. Join more science daught...
# 299  Type film soon back nearly.\nCold once purpose...
#
# [300 rows x 8 columns]

# %%
# Seats
seats = []
seat_types = ["Regular", "VIP", "Wheelchair"]
seat_status = ["Available", "Reserved", "Sold"]
seat_status_weights = [0.7, 0.2, 0.1]
seat_types_weights = [0.7, 0.2, 0.1]
for venue_id in range(1, venue_num + 1):
    for seat_number in range(1, seat_num + 1):  # 1000 seats per venue
        section_num = int(seat_number / 30 / 10)
        row_num = int(seat_number / 30) % 10
        seats.append({
            "venue_id": venue_id,
            "seat_number": seat_number,
            "section": f"Section-{section_num}",
            "row": f"Row-{row_num}",
            "seat_type": random.choices(seat_types, seat_types_weights)[0],
            "status": random.choices(seat_status, seat_status_weights)[0],
        })
        
seats_df = pd.DataFrame(seats)

print(seats_df)
# Out:
#        venue_id  seat_number     section    row   seat_type     status
# 0             1            1   Section-0  Row-0     Regular   Reserved
# 1             1            2   Section-0  Row-0         VIP  Available
# 2             1            3   Section-0  Row-0     Regular   Reserved
# 3             1            4   Section-0  Row-0     Regular  Available
# 4             1            5   Section-0  Row-0     Regular  Available
# ...         ...          ...         ...    ...         ...        ...
# 59995        20         2996   Section-9  Row-9     Regular   Reserved
# 59996        20         2997   Section-9  Row-9     Regular  Available
# 59997        20         2998   Section-9  Row-9  Wheelchair  Available
# 59998        20         2999   Section-9  Row-9     Regular  Available
# 59999        20         3000  Section-10  Row-0     Regular  Available
#
# [60000 rows x 6 columns]

# %%
import pandas as pd
import random
import numpy as np
from faker import Faker


orders = []
payments = []
tickets = []
order_statuses = ["Paid", "Pending", "Canceled"]
ticket_statuses = ["Youth", "Adult", "Senior"] # youth, adult, senior
payment_methods = ["Credit Card", "PayPal", "Bank Transfer"]
payment_statuses = ["Pending", "Completed", "Failed"]
payment_statuses_weights = [0.7, 0.2, 0.1]
ticket_statuses_weights = [0.7, 0.2, 0.1]
order_statuses_weights = [0.7, 0.2, 0.1]
for i in range(1, order_num + 1):
    orders.append({
        "order_id": i,
        "user_id": random.randint(1, user_num),
        "total_amount": round(random.uniform(100, 1000), 2),
        "order_date": fake.date_time_this_year(),
        "status": random.choices(order_statuses, order_statuses_weights)[0],
    })
    
    if (orders[i-1]['status'] == 'Paid'):
        total_amount = 0
        for j in range(random.randint(1, 3)):
            event = random.randint(1, event_num)
            ticket = {
                "ticket_id": len(tickets) + 1,
                "event_id": event,
                "order_id": i,
                "venue_id": 0,
                "seat_number": 0,
                "price": round(random.uniform(50, 200), 2),
                "type": random.choices(ticket_statuses, ticket_statuses_weights)[0],
            }
            
            while True:
                seat = random.choice(seats)
                if (seat['status'] != "Available"):
                    continue
                if ((seat['venue_id'], seat['seat_number'], event) not in [(t['venue_id'], t['seat_number'], t['event_id']) for t in tickets]):
                    ticket['venue_id'] = seat['venue_id']
                    ticket['seat_number'] = seat['seat_number']
                    break
                
            tickets.append(ticket)
            total_amount += ticket['price']
            
            seat['status'] = "Sold"

        payment = {
            "payment_id": len(payments) + 1,
            "order_id": i,
            "payment_date": fake.date_time_this_year(),
            "amount": total_amount,
            "method": random.choice(payment_methods),
            "status": "Completed",
        }
        payments.append(payment)
    elif (orders[i-1]['status'] == 'Pending'):
        payment = {
            "payment_id": len(payments) + 1,
            "order_id": i,
            "payment_date": fake.date_time_this_year(),
            "amount": orders[i-1]['total_amount'],
            "method": random.choice(payment_methods),
            "status": "Pending",
        }
        payments.append(payment)
        
        
orders_df = pd.DataFrame(orders)
orders_df.to_csv("orders.csv", index=False)

payments_df = pd.DataFrame(payments)
payments_df.to_csv("payments.csv", index=False)

tickets_df = pd.DataFrame(tickets)
tickets_df.to_csv("tickets.csv", index=False)

seats_df = pd.DataFrame(seats)
seats_df.to_csv("seats.csv", index=False)

print(orders_df)
# Out:
#       order_id  user_id  total_amount                 order_date    status
# 0            1     3593        213.34 2024-10-24 08:51:51.774968   Pending
# 1            2     7524        747.88 2024-01-20 10:35:55.604240  Canceled
# 2            3     3914        316.32 2024-02-03 12:36:06.468192   Pending
# 3            4    18530        566.90 2024-03-10 16:19:12.114207      Paid
# 4            5    18456        874.46 2024-02-07 07:41:57.949998      Paid
# ...        ...      ...           ...                        ...       ...
# 9995      9996     1592        626.37 2024-06-21 10:45:25.883289      Paid
# 9996      9997    15890        206.91 2024-01-06 04:38:14.738010  Canceled
# 9997      9998    11509        620.43 2024-02-03 11:05:56.689479   Pending
# 9998      9999    13929        769.64 2024-03-23 16:50:58.830340  Canceled
# 9999     10000     5420        928.72 2024-12-06 14:06:04.447428      Paid
#
# [10000 rows x 5 columns]

# %%
# check if every ticket has only appear once in every seat
