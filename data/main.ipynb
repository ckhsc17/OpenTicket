# %%
# Incase you don't have faker installed
! pip3 install faker
# Out:
# Requirement already satisfied: faker in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (33.0.0)
# Requirement already satisfied: python-dateutil>=2.4 in /Users/nono/Library/Python/3.12/lib/python/site-packages (from faker) (2.9.0.post0)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from faker) (4.11.0)
# Requirement already satisfied: six>=1.5 in /Users/nono/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.4->faker) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
import pandas as pd
import random
from faker import Faker

fake = Faker()

# Global Variables
user_num = 20000
venue_num = 20
event_num = 300
payment_num = 5000
order_num = 30000
ticket_num = 2000
seat_num = 2000
venues = []

# Users
users = []
roles = ['admin', 'user', 'organizer']
weights = [0.1, 0.7, 0.2]
for i in range(1, user_num + 1):
    user = {
        "user_id": i,
        "username": fake.user_name(),
        "password": fake.password(),
        "email": fake.email(),
        "phone": fake.phone_number(),
        "role": random.choices(roles, weights)[0],
        "created_at": fake.date_this_decade()
    }
    users.append(user)
    
users_df = pd.DataFrame(users)
users_df.to_csv("users.csv", index=False)
print(users_df)

# Some variables
admin_users = users_df[users_df['role'] == 'admin'].count()[0]
user_users = users_df[users_df['role'] == 'user'].count()[0]
organizer_users = users_df[users_df['role'] == 'organizer'].count()[0]
organizers = users_df[users_df['role'] == 'organizer']

print(f"Admin Users: {admin_users}")
print(f"User Users: {user_users}")
print(f"Organizer Users: {organizer_users}")
# Out:
#        user_id       username    password                      email  \
# 0            1  nicholscarlos  OC0NHmPh@K   shannoncohen@example.com
# 1            2      kristen95  $&GZt2232+    stephanie27@example.net
# 2            3          jim67  90_)3WTt+r   daviddonovan@example.net
# 3            4        nancy29  ifER&e&R_8          mroth@example.com
# 4            5        cturner  )4&8YNs$%*         ovilla@example.org
# ...        ...            ...         ...                        ...
# 19995    19996   sandraconner  %xJK8*l7M6        bhowell@example.com
# 19996    19997  porterbrandon  D_)_8NIu%k  johnsonangela@example.net
# 19997    19998    janetpineda  *Y2qH3e#Zm     ahenderson@example.org
# 19998    19999          nreed  z*I7VvIiQ@       thomas18@example.org
# 19999    20000    matabrandon  vy1I#gdc(4   matthewmarsh@example.org
#
#                         phone       role  created_at
# 0           738-704-1366x4914       user  2021-02-03
# 1          (710)369-8335x7296       user  2023-06-18
# 2           224-331-8125x7073  organizer  2021-05-11
# 3                  4798225744       user  2021-07-12
# 4      001-729-847-0527x48850       user  2022-10-17
# ...                       ...        ...         ...
# 19995     (633)680-0392x48214  organizer  2022-08-09
# 19996        455.341.0634x084      admin  2022-01-17
# 19997      410.989.6389x53070       user  2024-09-18
# 19998            449-494-8643       user  2024-04-18
# 19999  001-689-387-8724x07709       user  2021-09-18
#
# [20000 rows x 7 columns]
# Admin Users: 2059
# User Users: 13923
# Organizer Users: 4018
# /var/folders/p_/wcg3qcf14tjcjw_8md95qf_m0000gn/T/ipykernel_80887/334346936.py:38: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   admin_users = users_df[users_df['role'] == 'admin'].count()[0]
# /var/folders/p_/wcg3qcf14tjcjw_8md95qf_m0000gn/T/ipykernel_80887/334346936.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   user_users = users_df[users_df['role'] == 'user'].count()[0]
# /var/folders/p_/wcg3qcf14tjcjw_8md95qf_m0000gn/T/ipykernel_80887/334346936.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   organizer_users = users_df[users_df['role'] == 'organizer'].count()[0]

# %%
# Venues
for i in range(1, venue_num + 1):
    venues.append({
        "venue_id": i,
        "venue_name": fake.company(),
        "address": fake.address(),
        "city": fake.city(),
        "capacity": random.randint(1000, 10000)
    })
venues_df = pd.DataFrame(venues)
venues_df.to_csv("venues.csv", index=False)

print(venues_df)
# Out:
#     venue_id                   venue_name  \
# 0          1   Allen, Hernandez and Smith
# 1          2                  Bennett Ltd
# 2          3                    Smith PLC
# 3          4      Nelson, Poole and Evans
# 4          5                 Collins-Mayo
# 5          6   Coleman, Charles and Brown
# 6          7                   Rivera PLC
# 7          8              Dawson and Sons
# 8          9    Martinez, Page and Harris
# 9         10                Holmes-Foster
# 10        11                   Martin Inc
# 11        12             Mcguire and Sons
# 12        13                    Riley Ltd
# 13        14  Nichols, Medina and Hoffman
# 14        15   Adams, Franklin and Greene
# 15        16               Cunningham Ltd
# 16        17      Cox, Williams and Huber
# 17        18                    Lewis LLC
# 18        19               Ingram-Johnson
# 19        20                  Dean-Reilly
#
#                                               address                city  \
# 0        4588 Alexander Crescent\nMonicaton, PW 12389         New Melinda
# 1           65486 Lauren Parkway\nPoncetown, VA 64023       Port Lawrence
# 2       438 Lauren Corner Apt. 989\nMaybury, OH 62115           Port Mike
# 3        99808 Bailey Streets\nNicholasport, OR 42950         Rebeccastad
# 4                    PSC 1561, Box 3279\nAPO AA 70534          Morenofort
# 5                    PSC 2369, Box 7742\nAPO AA 00686    South Dennisside
# 6            05344 Amber Knolls\nCarrieland, UT 68841       Chaneyborough
# 7           52512 Taylor Mall\nStevensmouth, VA 73088          Cooperfurt
# 8   449 Fields Shoal Apt. 724\nSouth Autumnchester...     Port Geraldview
# 9   306 Ashlee Trafficway Suite 763\nNew Patricia,...   North Garyborough
# 10    40693 Deborah Motorway\nBrendaborough, NH 09679    West Tiffanyfort
# 11                   Unit 8690 Box 8912\nDPO AP 50517  North Jimmyborough
# 12  89640 Barnes Springs Apt. 150\nLaurenside, PA ...           Lake Anna
# 13  9273 Stephanie Orchard Suite 544\nWest Larryvi...     Lake Josephfurt
# 14             337 Taylor Isle\nJoshuamouth, ID 10039         Timothyport
# 15                   PSC 3932, Box 6820\nAPO AP 35641         Dwaynehaven
# 16              720 Baker Vista\nAliciaport, LA 68448         East Yvonne
# 17   23107 Jordan Lane Apt. 630\nNathanland, KY 21102       Middletonview
# 18      592 Romero Divide\nLake Richardside, OH 20125         West Angela
# 19            226 Nelson Tunnel\nWendyville, WY 97977          Brianburgh
#
#     capacity
# 0       3848
# 1       6820
# 2       6853
# 3       6848
# 4       2294
# 5       3944
# 6       1049
# 7       7701
# 8       7679
# 9       5316
# 10      5085
# 11      4660
# 12      7204
# 13      8903
# 14      5089
# 15      7252
# 16      9329
# 17      8803
# 18      6149
# 19      1634

# %%
# Events
events = []
organize = []
statuses = ["Scheduled", "Canceled", "Completed"]
statuses_weights = [0.7, 0.1, 0.2]
for i in range(1, event_num + 1):
    events.append({
        "event_id": i,
        "event_name": fake.catch_phrase(),
        "performer": fake.name(),
        "event_date": fake.date_this_year(),
        "venue_id": random.randint(1, venue_num),
        "organizer_id": random.choice(organizers['user_id'].tolist()),
        "status": random.choices(statuses, statuses_weights)[0],
        "description": fake.text()
    })
    
    organize.append({
        "organizer_id": events[-1]["organizer_id"],
        "event_id": i
    })
events_df = pd.DataFrame(events)
events_df.to_csv("events.csv", index=False)

organize_df = pd.DataFrame(organize)
organize_df.to_csv("organize.csv", index=False)

print(events_df)
# Out:
#      event_id                                        event_name  \
# 0           1                Cross-platform analyzing moderator
# 1           2                         Total tangible encryption
# 2           3                    Universal user-facing extranet
# 3           4                       Persistent radical leverage
# 4           5             Function-based incremental monitoring
# ..        ...                                               ...
# 295       296                            Managed methodical hub
# 296       297                     Digitized methodical forecast
# 297       298                      Secured bottom-line strategy
# 298       299  Fully-configurable solution-oriented flexibility
# 299       300            Quality-focused web-enabled definition
#
#                performer  event_date  venue_id  organizer_id     status  \
# 0             Megan Page  2024-06-29        13          7057  Scheduled
# 1         Blake Richards  2024-04-17         2         12555  Completed
# 2    Christopher Barrett  2024-08-12         3         10866  Completed
# 3             Scott Todd  2024-09-03         5         17833  Scheduled
# 4         Anthony Martin  2024-03-14         6         12870  Scheduled
# ..                   ...         ...       ...           ...        ...
# 295    Dr. Sarah Mendoza  2024-04-19        10         17581  Scheduled
# 296   Elizabeth Anderson  2024-06-29         6         11439  Scheduled
# 297          Robin Brown  2024-07-24         3         12986  Scheduled
# 298         Joseph Klein  2024-01-11         7          3968  Completed
# 299         Joseph Scott  2024-01-31        14         13534  Completed
#
#                                            description
# 0    Name single suggest. Deal involve among despit...
# 1    Anyone goal and world understand. Where study ...
# 2    Read degree age no. Example beat although go h...
# 3    Wait industry box PM weight. Exactly network s...
# 4    Ready family management agent site recognize d...
# ..                                                 ...
# 295  Plan under everybody throw police beyond. Sign...
# 296  Stock city be against everything decision. Dar...
# 297  Certainly she dark include between order. Mill...
# 298  Teacher loss make put computer off seven.\nAbo...
# 299  Meet during something plan hotel. People facto...
#
# [300 rows x 8 columns]

# %%
# Seats
seats = []
seat_types = ["Regular", "VIP", "Wheelchair"]
seat_types_weights = [0.7, 0.2, 0.1]
for venue_id in range(1, venue_num + 1):
    for seat_number in range(1, seat_num):  # 1000 seats per venue
        seats.append({
            "venue_id": venue_id,
            "seat_number": seat_number,
            "section": f"Section-{random.randint(1, 10)}",
            "row": f"Row-{random.randint(1, 40)}",
            "seat_type": random.choices(seat_types, seat_types_weights)[0],
        })
seats_df = pd.DataFrame(seats)
seats_df.to_csv("seats.csv", index=False)

print(seats_df)
# Out:
#        venue_id  seat_number    section     row seat_type
# 0             1            1  Section-3   Row-2   Regular
# 1             1            2  Section-4  Row-26   Regular
# 2             1            3  Section-1  Row-36   Regular
# 3             1            4  Section-5  Row-16   Regular
# 4             1            5  Section-1  Row-14   Regular
# ...         ...          ...        ...     ...       ...
# 39975        20         1995  Section-6   Row-5       VIP
# 39976        20         1996  Section-9  Row-13   Regular
# 39977        20         1997  Section-8  Row-18       VIP
# 39978        20         1998  Section-3  Row-27   Regular
# 39979        20         1999  Section-4  Row-24   Regular
#
# [39980 rows x 5 columns]

# %%
import pandas as pd
import random
import numpy as np
from faker import Faker

fake = Faker()

orders = []
payments = []
tickets = []
order_statuses = ["Pending", "Paid", "Canceled"]
ticket_statuses = ["Youth", "Adult", "Senior"] # youth, adult, senior
payment_methods = ["Credit Card", "PayPal", "Bank Transfer"]
payment_statuses = ["Pending", "Completed", "Failed"]
payment_statuses_weights = [0.7, 0.2, 0.1]
ticket_statuses_weights = [0.7, 0.2, 0.1]
order_statuses_weights = [0.7, 0.2, 0.1]
for i in range(1, order_num + 1):
    orders.append({
        "order_id": i,
        "user_id": random.randint(1, user_num),
        "total_amount": round(random.uniform(100, 1000), 2),
        "order_date": fake.date_time_this_year(),
        "status": random.choices(order_statuses, order_statuses_weights)[0],
    })
    
    if (orders[i-1]['status'] == 'Paid'):
        total_amount = 0
        for j in range(random.randint(1, 5)):
            event = random.randint(1, event_num)
            ticket = {
                "ticket_id": len(tickets) + 1,
                "event_id": event,
                "order_id": i,
                "venue_id": 0,
                "seat_number": 0,
                "price": round(random.uniform(50, 200), 2),
                "status": random.choices(ticket_statuses, ticket_statuses_weights)[0],
            }
            
            while True:
                seat = random.choice(seats)
                if ((seat['venue_id'], seat['seat_number'], event) not in [(t['venue_id'], t['seat_number'], t['event_id']) for t in tickets]):
                    ticket['venue_id'] = seat['venue_id']
                    ticket['seat_number'] = seat['seat_number']
                    break
                
            tickets.append(ticket)
            total_amount += ticket['price']

        payment = {
            "payment_id": len(payments) + 1,
            "order_id": i,
            "payment_date": fake.date_time_this_year(),
            "amount": total_amount,
            "method": random.choice(payment_methods),
            "status": "Completed",
        }
        payments.append(payment)
    elif (orders[i-1]['status'] == 'Pending'):
        payment = {
            "payment_id": len(payments) + 1,
            "order_id": i,
            "payment_date": fake.date_time_this_year(),
            "amount": orders[i-1]['total_amount'],
            "method": random.choice(payment_methods),
            "status": "Pending",
        }
        payments.append(payment)
        
        
orders_df = pd.DataFrame(orders)
orders_df.to_csv("orders.csv", index=False)

payments_df = pd.DataFrame(payments)
payments_df.to_csv("payments.csv", index=False)

tickets_df = pd.DataFrame(tickets)
tickets_df.to_csv("tickets.csv", index=False)

print(orders_df)
# Out:
#        order_id  user_id  total_amount                 order_date    status
# 0             1      820        698.25 2024-09-04 11:45:44.309440   Pending
# 1             2     4164        994.47 2024-08-03 18:31:15.898121      Paid
# 2             3     2867        583.78 2024-03-30 10:32:38.634373  Canceled
# 3             4    16425        112.42 2024-07-03 12:27:50.628989   Pending
# 4             5     7648        848.16 2024-03-26 02:43:59.774989      Paid
# ...         ...      ...           ...                        ...       ...
# 29995     29996    17214        851.21 2024-11-23 13:23:43.318642   Pending
# 29996     29997    17325        748.83 2024-01-19 11:05:35.523448  Canceled
# 29997     29998    11070        838.02 2024-05-11 07:44:17.424138      Paid
# 29998     29999     6902        509.39 2024-07-22 14:58:57.616083   Pending
# 29999     30000    18039        271.54 2024-01-26 14:00:14.502178   Pending
#
# [30000 rows x 5 columns]

# %%
# check if every ticket has only appear once in every seat
