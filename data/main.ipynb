# %%
# Incase you don't have faker installed
! pip3 install faker
# Out:
# Requirement already satisfied: faker in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (33.0.0)
# Requirement already satisfied: python-dateutil>=2.4 in /Users/nono/Library/Python/3.12/lib/python/site-packages (from faker) (2.9.0.post0)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from faker) (4.11.0)
# Requirement already satisfied: six>=1.5 in /Users/nono/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.4->faker) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
import pandas as pd
import random
from faker import Faker

fake = Faker()

# Global Variables
user_num = 20000
venue_num = 20
event_num = 300
payment_num = 5000
order_num = 10000
ticket_num = 2000
seat_num = 3000
venues = []

# Users
users = []
roles = ['admin', 'user', 'organizer']
weights = [0.1, 0.7, 0.2]
for i in range(1, user_num + 1):
    user = {
        "user_id": i,
        "username": fake.user_name(),
        "password": fake.password(),
        "email": fake.email(),
        "phone": fake.phone_number(),
        "role": random.choices(roles, weights)[0],
        "created_at": fake.date_this_decade()
    }
    users.append(user)
    
users_df = pd.DataFrame(users)
users_df.to_csv("users.csv", index=False)
print(users_df)

# Some variables
admin_users = users_df[users_df['role'] == 'admin'].count()[0]
user_users = users_df[users_df['role'] == 'user'].count()[0]
organizer_users = users_df[users_df['role'] == 'organizer'].count()[0]
organizers = users_df[users_df['role'] == 'organizer']

print(f"Admin Users: {admin_users}")
print(f"User Users: {user_users}")
print(f"Organizer Users: {organizer_users}")
# Out:
#        user_id          username    password                       email  \
# 0            1  mckenziepatricia  d2kIW1Uz(D    hortonjoshua@example.com
# 1            2      johnsonbryan  !Yn_2Txvkx          zyoung@example.org
# 2            3         barbara88  #(gb1jNhT6  jeffreyfrancis@example.com
# 3            4      danielvaldez  tl8QaMTY#5    combsmelissa@example.org
# 4            5           brian55  +M28WZi1GI        leonjohn@example.net
# ...        ...               ...         ...                         ...
# 19995    19996            kyle21  $$)P6OCxNA   kaitlynmartin@example.net
# 19996    19997             hpage  %WC$q5Ljc@        wandrews@example.org
# 19997    19998        huntjoshua  %&E2PeDp#U        andrea28@example.net
# 19998    19999  marshallbenjamin  &qTu*gAn*0  austincourtney@example.com
# 19999    20000        howardmary  nYXKp@p9(6   nicholashardy@example.org
#
#                        phone       role  created_at
# 0           001-901-696-1798       user  2023-11-20
# 1                 9427008851       user  2021-02-24
# 2              (440)558-4658       user  2022-07-31
# 3               874.440.7090       user  2021-04-28
# 4      +1-403-323-6903x84144  organizer  2020-03-30
# ...                      ...        ...         ...
# 19995    (252)615-7721x92007       user  2021-05-26
# 19996           388-510-9373       user  2024-05-27
# 19997       724-404-0069x959       user  2020-01-05
# 19998          (737)296-9065       user  2023-02-17
# 19999     200-517-0271x57272       user  2020-11-02
#
# [20000 rows x 7 columns]
# Admin Users: 2017
# User Users: 13913
# Organizer Users: 4070
# /var/folders/p_/wcg3qcf14tjcjw_8md95qf_m0000gn/T/ipykernel_17434/3396301955.py:38: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   admin_users = users_df[users_df['role'] == 'admin'].count()[0]
# /var/folders/p_/wcg3qcf14tjcjw_8md95qf_m0000gn/T/ipykernel_17434/3396301955.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   user_users = users_df[users_df['role'] == 'user'].count()[0]
# /var/folders/p_/wcg3qcf14tjcjw_8md95qf_m0000gn/T/ipykernel_17434/3396301955.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   organizer_users = users_df[users_df['role'] == 'organizer'].count()[0]

# %%
# Venues
for i in range(1, venue_num + 1):
    venues.append({
        "venue_id": i,
        "venue_name": fake.company(),
        "address": fake.address(),
        "city": fake.city(),
        "capacity": random.randint(1000, 10000)
    })
venues_df = pd.DataFrame(venues)
venues_df.to_csv("venues.csv", index=False)

print(venues_df)
# Out:
#     venue_id                        venue_name  \
# 0          1                         Fritz PLC
# 1          2             Smith, James and Todd
# 2          3                      Bradshaw Inc
# 3          4                    Wiley and Sons
# 4          5                        Chung-Sims
# 5          6                      Steele Group
# 6          7                     Fleming-Ortiz
# 7          8                   Ingram-Clements
# 8          9     Chandler, Ortiz and Hernandez
# 9         10                         Davis Inc
# 10        11             Cook, Reed and Patton
# 11        12                    Walsh-Gonzalez
# 12        13                        Nelson LLC
# 13        14  Humphrey, Nicholson and Anderson
# 14        15                       Jackson Inc
# 15        16                       Zavala-Mack
# 16        17         Morgan, Miller and Fuller
# 17        18     Mullins, Sheppard and Stewart
# 18        19        Lutz, Nguyen and Nicholson
# 19        20                     Kirk and Sons
#
#                                               address                city  \
# 0    521 Cooper Run Suite 480\nSamanthaport, PW 95686      West Mariefurt
# 1       81054 Jake Port Apt. 220\nPort Rita, FL 72145        New Brittany
# 2       07967 Jennifer Underpass\nAngelport, UT 95545    New Sabrinamouth
# 3             845 Connie Branch\nHarrisside, OK 35849       East Jackview
# 4      9390 Lisa Alley\nLake Heatherchester, RI 51931      Jessicaborough
# 5            99292 Kelly Bridge\nRobertston, CO 72114          Thomasfort
# 6   376 Chad Streets Suite 482\nBrucechester, OK 8...    South Staceyberg
# 7               319 Shane Road\nLake Edward, CT 22313    North Julieville
# 8            341 Kevin Club\nChristopherton, PW 73546         South Ralph
# 9       2874 Matthew Turnpike\nWest Stephen, FL 19053       Vaughnchester
# 10                   Unit 5655 Box 8945\nDPO AP 15380     Lorraineborough
# 11                   Unit 1668 Box 4168\nDPO AA 21931    West Nicolemouth
# 12                   Unit 2002 Box 1772\nDPO AP 56705          Jameshaven
# 13  203 Mary Land Suite 171\nNew Josephborough, NY...       South Michael
# 14  087 Mcdonald Ridges Suite 719\nSouth Brandibur...      East Jasonfort
# 15  680 Lauren Fall Suite 912\nWest Paigefurt, SD ...         West Sheryl
# 16  7696 Kelsey Rapids Apt. 709\nEast Rebecca, VI ...            Lisaland
# 17             487 James Fork\nKennethmouth, PW 86396         Kristenfurt
# 18   954 Xavier Stream Apt. 990\nWaltertown, NE 66462           Lucasbury
# 19  10594 Edwards Summit Apt. 945\nFrancisborough,...  South Timothymouth
#
#     capacity
# 0       6786
# 1       3004
# 2       1231
# 3       9643
# 4       7489
# 5       8024
# 6       8296
# 7       2407
# 8       1024
# 9       1972
# 10      5616
# 11      4968
# 12      7310
# 13      4264
# 14      9352
# 15      4760
# 16      2225
# 17      3706
# 18      6748
# 19      4880

# %%
# Events
events = []
organize = []
statuses = ["Scheduled", "Canceled", "Completed"]
statuses_weights = [0.7, 0.1, 0.2]
for i in range(1, event_num + 1):
    events.append({
        "event_id": i,
        "event_name": fake.catch_phrase(),
        "performer": fake.name(),
        "event_date": fake.date_this_year(),
        "venue_id": random.randint(1, venue_num),
        "organizer_id": random.choice(organizers['user_id'].tolist()),
        "status": random.choices(statuses, statuses_weights)[0],
        "description": fake.text()
    })
    
    organize.append({
        "organizer_id": events[-1]["organizer_id"],
        "event_id": i
    })
events_df = pd.DataFrame(events)
events_df.to_csv("events.csv", index=False)

organize_df = pd.DataFrame(organize)
organize_df.to_csv("organize.csv", index=False)

print(events_df)
# Out:
#      event_id                           event_name             performer  \
# 0           1         Total client-server analyzer        Frank Odonnell
# 1           2          Enhanced coherent framework         Micheal Reyes
# 2           3              Diverse stable leverage       Jennifer Thomas
# 3           4         Polarized explicit algorithm          Sophia Mason
# 4           5  Secured homogeneous instruction set         Jordan Lawson
# ..        ...                                  ...                   ...
# 295       296  Organized zero tolerance neural-net            Jade Allen
# 296       297     Mandatory non-volatile framework         Dwayne Gentry
# 297       298            Integrated 24hour circuit       Stephen Padilla
# 298       299      Total bi-directional task-force      Clarence Collins
# 299       300   Stand-alone bottom-line definition  Dr. Jared Porter DVM
#
#      event_date  venue_id  organizer_id     status  \
# 0    2024-04-29        15          4426  Scheduled
# 1    2024-05-03        18         19876  Scheduled
# 2    2024-11-25         4         12930  Scheduled
# 3    2024-01-31        15          9307  Scheduled
# 4    2024-07-08         8         12899  Scheduled
# ..          ...       ...           ...        ...
# 295  2024-06-06         3         14480  Completed
# 296  2024-05-17        15         13328  Scheduled
# 297  2024-09-20        19          2114  Completed
# 298  2024-07-27        17          9402  Scheduled
# 299  2024-06-30        18         13523  Scheduled
#
#                                            description
# 0    Near mother Mrs suffer subject industry determ...
# 1    Produce those fine process shake cut better. L...
# 2    Plan customer mouth. Meet dark guess about nea...
# 3    Ball cut seat little mean. This true artist.\n...
# 4    Others after kid. Personal sound source today ...
# ..                                                 ...
# 295  Home machine rule college situation them. May ...
# 296  Trade across responsibility significant ask wh...
# 297  Shoulder agreement reduce majority move myself...
# 298       Shake door care. Pick style mean north kind.
# 299  Almost few need choice. Line as physical autho...
#
# [300 rows x 8 columns]

# %%
# Seats
seats = []
seat_types = ["Regular", "VIP", "Wheelchair"]
seat_status = ["Available", "Reserved", "Sold"]
seat_status_weights = [0.7, 0.2, 0.1]
seat_types_weights = [0.7, 0.2, 0.1]
for venue_id in range(1, venue_num + 1):
    for seat_number in range(1, seat_num):  # 1000 seats per venue
        seats.append({
            "venue_id": venue_id,
            "seat_number": seat_number,
            "section": f"Section-{random.randint(1, 10)}",
            "row": f"Row-{random.randint(1, 40)}",
            "seat_type": random.choices(seat_types, seat_types_weights)[0],
            "status": random.choices(seat_status, seat_status_weights)[0],
        })
        
seats_df = pd.DataFrame(seats)

print(seats_df)
# Out:
#        venue_id  seat_number     section     row   seat_type     status
# 0             1            1   Section-5  Row-26     Regular  Available
# 1             1            2   Section-9  Row-36     Regular   Reserved
# 2             1            3   Section-2  Row-31     Regular  Available
# 3             1            4   Section-8  Row-25         VIP   Reserved
# 4             1            5   Section-5   Row-8     Regular  Available
# ...         ...          ...         ...     ...         ...        ...
# 59975        20         2995   Section-8   Row-7     Regular   Reserved
# 59976        20         2996   Section-1   Row-4     Regular  Available
# 59977        20         2997  Section-10  Row-32     Regular  Available
# 59978        20         2998   Section-6  Row-18  Wheelchair  Available
# 59979        20         2999   Section-6  Row-35         VIP  Available
#
# [59980 rows x 6 columns]

# %%
import pandas as pd
import random
import numpy as np
from faker import Faker


orders = []
payments = []
tickets = []
order_statuses = ["Paid", "Pending", "Canceled"]
ticket_statuses = ["Youth", "Adult", "Senior"] # youth, adult, senior
payment_methods = ["Credit Card", "PayPal", "Bank Transfer"]
payment_statuses = ["Pending", "Completed", "Failed"]
payment_statuses_weights = [0.7, 0.2, 0.1]
ticket_statuses_weights = [0.7, 0.2, 0.1]
order_statuses_weights = [0.7, 0.2, 0.1]
for i in range(1, order_num + 1):
    orders.append({
        "order_id": i,
        "user_id": random.randint(1, user_num),
        "total_amount": round(random.uniform(100, 1000), 2),
        "order_date": fake.date_time_this_year(),
        "status": random.choices(order_statuses, order_statuses_weights)[0],
    })
    
    if (orders[i-1]['status'] == 'Paid'):
        total_amount = 0
        for j in range(random.randint(1, 3)):
            event = random.randint(1, event_num)
            ticket = {
                "ticket_id": len(tickets) + 1,
                "event_id": event,
                "order_id": i,
                "venue_id": 0,
                "seat_number": 0,
                "price": round(random.uniform(50, 200), 2),
                "type": random.choices(ticket_statuses, ticket_statuses_weights)[0],
            }
            
            while True:
                seat = random.choice(seats)
                if (seat['status'] != "Available"):
                    continue
                if ((seat['venue_id'], seat['seat_number'], event) not in [(t['venue_id'], t['seat_number'], t['event_id']) for t in tickets]):
                    ticket['venue_id'] = seat['venue_id']
                    ticket['seat_number'] = seat['seat_number']
                    break
                
            tickets.append(ticket)
            total_amount += ticket['price']
            
            seat['status'] = "Sold"

        payment = {
            "payment_id": len(payments) + 1,
            "order_id": i,
            "payment_date": fake.date_time_this_year(),
            "amount": total_amount,
            "method": random.choice(payment_methods),
            "status": "Completed",
        }
        payments.append(payment)
    elif (orders[i-1]['status'] == 'Pending'):
        payment = {
            "payment_id": len(payments) + 1,
            "order_id": i,
            "payment_date": fake.date_time_this_year(),
            "amount": orders[i-1]['total_amount'],
            "method": random.choice(payment_methods),
            "status": "Pending",
        }
        payments.append(payment)
        
        
orders_df = pd.DataFrame(orders)
orders_df.to_csv("orders.csv", index=False)

payments_df = pd.DataFrame(payments)
payments_df.to_csv("payments.csv", index=False)

tickets_df = pd.DataFrame(tickets)
tickets_df.to_csv("tickets.csv", index=False)

seats_df = pd.DataFrame(seats)
seats_df.to_csv("seats.csv", index=False)

print(orders_df)
# Out:
#       order_id  user_id  total_amount                 order_date   status
# 0            1     4413        321.37 2024-02-06 15:24:22.341149  Pending
# 1            2    11510        412.75 2024-01-19 22:33:27.725912     Paid
# 2            3    11569        108.75 2024-04-24 22:01:38.075491     Paid
# 3            4    12934        793.26 2024-04-04 03:00:27.471156     Paid
# 4            5    16723        170.74 2024-05-06 01:04:54.403748     Paid
# ...        ...      ...           ...                        ...      ...
# 9995      9996    17850        572.75 2024-08-02 20:41:13.125762     Paid
# 9996      9997     1628        895.84 2024-04-18 14:12:02.880590     Paid
# 9997      9998    18373        251.61 2024-07-29 03:35:06.292297     Paid
# 9998      9999     4912        803.94 2024-04-29 15:23:08.653049     Paid
# 9999     10000     8388        138.50 2024-04-28 00:44:49.027876     Paid
#
# [10000 rows x 5 columns]

# %%
# check if every ticket has only appear once in every seat
